# %% [markdown]
# Viktor Vironski (4330455), Andreas Disser Matr.-Nr.: 5984875

# %%
import torch

# %%
import numpy as np

# %%
from sklearn import datasets

# %%
import pandas as pd

# %% [markdown]
# # Exercise 1: Min-Max normalization

# %% [markdown]
# ### scale between $[a,b]$
#
# $x^\prime = a + \frac{(x-min(x))*(b-a)}{max(x)-min(x)}$

# %%
def min_max_scale(data, min_range=0, max_range=1):
    """the valuel of data gets changed in the function"""
    new_data = data
    min_value = np.amin(new_data)
    max_value = np.amax(new_data)
    print(f"The minimum value is: {min_value}")
    print(f"The maximum value is: {max_value}")
    new_data -= min_value
    new_data *= (max_range - min_range)
    new_data = np.divide(new_data, (max_value - min_value))
    
    return new_data

# %%
iris = datasets.load_iris()

# %%
iris.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
iris_data = iris["data"]
p_iris_data = pd.DataFrame(iris_data, columns=["Sepal length","Sepal width","Petal length","Petal width"])
p_iris_data
# Out:
#      Sepal length  Sepal width  Petal length  Petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# # a) scale all featrues separately

# %%
min_max_scale(iris_data[0,:])
# Out:
# The minimum value is: 0.2
# The maximum value is: 5.1
# array([1.        , 0.67346939, 0.24489796, 0.        ])

# %%
feature_scaled_iris = np.zeros((150,4))
for i in range(len(iris_data)):
    feature_scaled_iris[i,:] = min_max_scale(iris_data[i,:])
    
feature_scaled_iris
# Out:
# The minimum value is: 0.0
# The maximum value is: 4.8999999999999995
# The minimum value is: 0.2
# The maximum value is: 4.9
# The minimum value is: 0.2
# The maximum value is: 4.7
# The minimum value is: 0.2
# The maximum value is: 4.6
# The minimum value is: 0.2
# The maximum value is: 5.0
# The minimum value is: 0.4
# The maximum value is: 5.4
# The minimum value is: 0.3
# The maximum value is: 4.6
# The minimum value is: 0.2
# The maximum value is: 5.0
# The minimum value is: 0.2
# The maximum value is: 4.4
# The minimum value is: 0.1
# The maximum value is: 4.9
# The minimum value is: 0.2
# The maximum value is: 5.4
# The minimum value is: 0.2
# The maximum value is: 4.8
# The minimum value is: 0.1
# The maximum value is: 4.8
# The minimum value is: 0.1
# The maximum value is: 4.3
# The minimum value is: 0.2
# The maximum value is: 5.8
# The minimum value is: 0.4
# The maximum value is: 5.7
# The minimum value is: 0.4
# The maximum value is: 5.4
# The minimum value is: 0.3
# The maximum value is: 5.1
# The minimum value is: 0.3
# The maximum value is: 5.7
# The minimum value is: 0.3
# The maximum value is: 5.1
# The minimum value is: 0.2
# The maximum value is: 5.4
# The minimum value is: 0.4
# The maximum value is: 5.1
# The minimum value is: 0.2
# The maximum value is: 4.6
# The minimum value is: 0.5
# The maximum value is: 5.1
# The minimum value is: 0.2
# The maximum value is: 4.8
# The minimum value is: 0.2
# The maximum value is: 5.0
# The minimum value is: 0.4
# The maximum value is: 5.0
# The minimum value is: 0.2
# The maximum value is: 5.2
# The minimum value is: 0.2
# The maximum value is: 5.2
# The minimum value is: 0.2
# The maximum value is: 4.7
# The minimum value is: 0.2
# The maximum value is: 4.8
# The minimum value is: 0.4
# The maximum value is: 5.4
# The minimum value is: 0.1
# The maximum value is: 5.2
# The minimum value is: 0.2
# The maximum value is: 5.5
# The minimum value is: 0.2
# The maximum value is: 4.9
# The minimum value is: 0.2
# The maximum value is: 5.0
# The minimum value is: 0.2
# The maximum value is: 5.5
# The minimum value is: 0.1
# The maximum value is: 4.9
# The minimum value is: 0.2
# The maximum value is: 4.4
# The minimum value is: 0.2
# The maximum value is: 5.1
# The minimum value is: 0.3
# The maximum value is: 5.0
# The minimum value is: 0.3
# The maximum value is: 4.5
# The minimum value is: 0.2
# The maximum value is: 4.4
# The minimum value is: 0.6
# The maximum value is: 5.0
# The minimum value is: 0.4
# The maximum value is: 5.1
# The minimum value is: 0.3
# The maximum value is: 4.8
# The minimum value is: 0.2
# The maximum value is: 5.1
# The minimum value is: 0.2
# The maximum value is: 4.6
# The minimum value is: 0.2
# The maximum value is: 5.3
# The minimum value is: 0.2
# The maximum value is: 5.0
# The minimum value is: 1.4
# The maximum value is: 7.0
# The minimum value is: 1.5
# The maximum value is: 6.4
# The minimum value is: 1.5
# The maximum value is: 6.9
# The minimum value is: 1.3
# The maximum value is: 5.5
# The minimum value is: 1.5
# The maximum value is: 6.5
# The minimum value is: 1.3
# The maximum value is: 5.7
# The minimum value is: 1.6
# The maximum value is: 6.3
# The minimum value is: 1.0
# The maximum value is: 4.9
# The minimum value is: 1.3
# The maximum value is: 6.6
# The minimum value is: 1.4
# The maximum value is: 5.2
# The minimum value is: 1.0
# The maximum value is: 5.0
# The minimum value is: 1.5
# The maximum value is: 5.9
# The minimum value is: 1.0
# The maximum value is: 6.0
# The minimum value is: 1.4
# The maximum value is: 6.1
# The minimum value is: 1.3
# The maximum value is: 5.6
# The minimum value is: 1.4
# The maximum value is: 6.7
# The minimum value is: 1.5
# The maximum value is: 5.6
# The minimum value is: 1.0
# The maximum value is: 5.8
# The minimum value is: 1.5
# The maximum value is: 6.2
# The minimum value is: 1.1
# The maximum value is: 5.6
# The minimum value is: 1.8
# The maximum value is: 5.9
# The minimum value is: 1.3
# The maximum value is: 6.1
# The minimum value is: 1.5
# The maximum value is: 6.3
# The minimum value is: 1.2
# The maximum value is: 6.1
# The minimum value is: 1.3
# The maximum value is: 6.4
# The minimum value is: 1.4
# The maximum value is: 6.6
# The minimum value is: 1.4
# The maximum value is: 6.8
# The minimum value is: 1.7
# The maximum value is: 6.7
# The minimum value is: 1.5
# The maximum value is: 6.0
# The minimum value is: 1.0
# The maximum value is: 5.7
# The minimum value is: 1.1
# The maximum value is: 5.5
# The minimum value is: 1.0
# The maximum value is: 5.5
# The minimum value is: 1.2
# The maximum value is: 5.8
# The minimum value is: 1.6
# The maximum value is: 6.0
# The minimum value is: 1.5
# The maximum value is: 5.4
# The minimum value is: 1.6
# The maximum value is: 6.0
# The minimum value is: 1.5
# The maximum value is: 6.7
# The minimum value is: 1.3
# The maximum value is: 6.3
# The minimum value is: 1.3
# The maximum value is: 5.6
# The minimum value is: 1.3
# The maximum value is: 5.5
# The minimum value is: 1.2
# The maximum value is: 5.5
# The minimum value is: 1.4
# The maximum value is: 6.1
# The minimum value is: 1.2
# The maximum value is: 5.8
# The minimum value is: 1.0
# The maximum value is: 5.0
# The minimum value is: 1.3
# The maximum value is: 5.6
# The minimum value is: 1.2
# The maximum value is: 5.7
# The minimum value is: 1.3
# The maximum value is: 5.7
# The minimum value is: 1.3
# The maximum value is: 6.2
# The minimum value is: 1.1
# The maximum value is: 5.1
# The minimum value is: 1.3
# The maximum value is: 5.7
# The minimum value is: 2.5
# The maximum value is: 6.3
# The minimum value is: 1.9
# The maximum value is: 5.8
# The minimum value is: 2.1
# The maximum value is: 7.1
# The minimum value is: 1.8
# The maximum value is: 6.3
# The minimum value is: 2.2
# The maximum value is: 6.5
# The minimum value is: 2.1
# The maximum value is: 7.6
# The minimum value is: 1.7
# The maximum value is: 4.9
# The minimum value is: 1.8
# The maximum value is: 7.3
# The minimum value is: 1.8
# The maximum value is: 6.7
# The minimum value is: 2.5
# The maximum value is: 7.2
# The minimum value is: 2.0
# The maximum value is: 6.5
# The minimum value is: 1.9
# The maximum value is: 6.4
# The minimum value is: 2.1
# The maximum value is: 6.8
# The minimum value is: 2.0
# The maximum value is: 5.7
# The minimum value is: 2.4
# The maximum value is: 5.8
# The minimum value is: 2.3
# The maximum value is: 6.4
# The minimum value is: 1.8
# The maximum value is: 6.5
# The minimum value is: 2.2
# The maximum value is: 7.7
# The minimum value is: 2.3
# The maximum value is: 7.7
# The minimum value is: 1.5
# The maximum value is: 6.0
# The minimum value is: 2.3
# The maximum value is: 6.9
# The minimum value is: 2.0
# The maximum value is: 5.6
# The minimum value is: 2.0
# The maximum value is: 7.7
# The minimum value is: 1.8
# The maximum value is: 6.3
# The minimum value is: 2.1
# The maximum value is: 6.7
# The minimum value is: 1.8
# The maximum value is: 7.2
# The minimum value is: 1.8
# The maximum value is: 6.2
# The minimum value is: 1.8
# The maximum value is: 6.1
# The minimum value is: 2.1
# The maximum value is: 6.4
# The minimum value is: 1.6
# The maximum value is: 7.2
# The minimum value is: 1.9
# The maximum value is: 7.4
# The minimum value is: 2.0
# The maximum value is: 7.9
# The minimum value is: 2.2
# The maximum value is: 6.4
# The minimum value is: 1.5
# The maximum value is: 6.3
# The minimum value is: 1.4
# The maximum value is: 6.1
# The minimum value is: 2.3
# The maximum value is: 7.7
# The minimum value is: 2.4
# The maximum value is: 6.3
# The minimum value is: 1.8
# The maximum value is: 6.4
# The minimum value is: 1.8
# The maximum value is: 6.0
# The minimum value is: 2.1
# The maximum value is: 6.9
# The minimum value is: 2.4
# The maximum value is: 6.7
# The minimum value is: 2.3
# The maximum value is: 6.9
# The minimum value is: 1.9
# The maximum value is: 5.8
# The minimum value is: 2.3
# The maximum value is: 6.8
# The minimum value is: 2.5
# The maximum value is: 6.7
# The minimum value is: 2.3
# The maximum value is: 6.7
# The minimum value is: 1.9
# The maximum value is: 6.3
# The minimum value is: 2.0
# The maximum value is: 6.5
# The minimum value is: 2.3
# The maximum value is: 6.2
# The minimum value is: 1.8
# The maximum value is: 5.9
#        [1.        , 0.17777778, 0.75555556, 0.        ],
#        [1.        , 0.19148936, 0.72340426, 0.        ],
#        [1.        , 0.13513514, 0.81081081, 0.        ],
#        [1.        , 0.11764706, 0.79411765, 0.        ],
#        [1.        , 0.2195122 , 0.73170732, 0.        ],
#        [1.        , 0.25531915, 0.78723404, 0.        ],
#        [1.        , 0.29090909, 0.81818182, 0.        ],
#        [1.        , 0.05555556, 0.85185185, 0.        ],
#        [1.        , 0.15555556, 0.77777778, 0.        ],
#        [1.        , 0.19565217, 0.73913043, 0.        ],
#        [1.        , 0.22222222, 0.80555556, 0.        ],
#        [1.        , 0.14035088, 0.8245614 , 0.        ],
#        [1.        , 0.2       , 0.68888889, 0.        ],
#        [1.        , 0.26086957, 0.7826087 , 0.        ],
#        [1.        , 0.25925926, 0.77777778, 0.        ],
#        [1.        , 0.22727273, 0.68181818, 0.        ],
#        [1.        , 0.27906977, 0.72093023, 0.        ],
#        [1.        , 0.1627907 , 0.81395349, 0.        ],
#        [1.        , 0.25      , 0.75      , 0.        ],
#        [1.        , 0.16363636, 0.76363636, 0.        ],
#        [1.        , 0.30508475, 0.74576271, 0.        ],
#        [1.        , 0.14285714, 0.80952381, 0.        ],
#        [1.        , 0.27083333, 0.75      , 0.        ],
#        [1.        , 0.25531915, 0.89361702, 0.        ],
#        [1.        , 0.12962963, 0.7037037 , 0.        ],
#        [1.        , 0.25641026, 0.82051282, 0.        ],
#        [1.        , 0.2826087 , 0.80434783, 0.        ],
#        [1.        , 0.28571429, 0.71428571, 0.        ],
#        [1.        , 0.20833333, 0.6875    , 0.        ],
#        [1.        , 0.1627907 , 0.74418605, 0.        ],
#        [1.        , 0.17391304, 0.60869565, 0.        ],
#        [1.        , 0.20512821, 0.82051282, 0.        ],
#        [1.        , 0.2       , 0.8       , 0.        ],
#        [1.        , 0.19047619, 0.76190476, 0.        ],
#        [1.        , 0.15909091, 0.65909091, 0.        ],
#        [1.        , 0.13636364, 0.70454545, 0.        ],
#        [1.        , 0.22222222, 0.71111111, 0.        ],
#        [1.        , 0.28205128, 0.79487179, 0.        ],
#        [1.        , 0.29268293, 0.80487805, 0.        ]])

# %% [markdown]
# # b) scaling the entire dataset

# %%
scaled_all_data = min_max_scale(iris_data)
pd.DataFrame(scaled_all_data, columns=["Sepal length","Sepal width","Petal length","Petal width"])
# Out:
# The minimum value is: 0.0
# The maximum value is: 5.9
#      Sepal length  Sepal width  Petal length  Petal width
# 0        0.830508     0.559322      0.203390          0.0
# 1        0.796610     0.474576      0.203390          0.0
# 2        0.762712     0.508475      0.186441          0.0
# 3        0.745763     0.491525      0.220339          0.0
# 4        0.813559     0.576271      0.203390          0.0
# ..            ...          ...           ...          ...
# 145      0.745763     0.118644      0.491525          0.0
# 146      0.745763     0.101695      0.525424          0.0
# 147      0.762712     0.169492      0.542373          0.0
# 148      0.661017     0.186441      0.525424          0.0
# 149      0.694915     0.203390      0.559322          0.0
#
# [150 rows x 4 columns]

# %% [markdown]
# # tests
